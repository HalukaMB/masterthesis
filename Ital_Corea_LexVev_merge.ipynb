# %%
# coding: utf-8

# In[4]:

import pandas as pd
import re

# In[5]:

data = pd.read_csv('/Users/halukamaier-borst/Documents/CardiffUniversity/Master Thesis/masterthesis_code/CleanDatasets/resultslist.csv', header=None)


print(data.head(20))
# Out:
#            0
# 0   0.133333
# 1   0.000000
# 2   1.000000
# 3   0.000000
# 4   0.000000
# 5   2.000000
# 6  -0.307692
# 7   0.000000
# 8   3.000000
# 9   0.142857
# 10  0.000000
# 11  4.000000
# 12  0.000000
# 13  0.000000
# 14  5.000000
# 15  0.666667
# 16  0.000000
# 17  6.000000
# 18  0.666667
# 19  0.000000

# %%
a=2
alist=[]
for index, row in data.iterrows():
    a+=1
    if a%3==0:
        alist.append(row)
    else:
        pass
print(alist)
# Out:
# [0    0.133333
# Name: 0, dtype: float64, 0    0.0
# Name: 3, dtype: float64, 0   -0.307692
# Name: 6, dtype: float64, 0    0.142857
# Name: 9, dtype: float64, 0    0.0
# Name: 12, dtype: float64, 0    0.666667
# Name: 15, dtype: float64, 0    0.666667
# Name: 18, dtype: float64, 0    0.0
# Name: 21, dtype: float64, 0    1.0
# Name: 24, dtype: float64, 0    0.0
# Name: 27, dtype: float64, 0    0.4
# Name: 30, dtype: float64, 0    0.111111
# Name: 33, dtype: float64, 0    0.090909
# Name: 36, dtype: float64, 0    0.0
# Name: 39, dtype: float64, 0    0.090909
# Name: 42, dtype: float64, 0   -1.0
# Name: 45, dtype: float64, 0    0.0
# Name: 48, dtype: float64, 0    0.5
# Name: 51, dtype: float64, 0    0.25
# Name: 54, dtype: float64, 0    0.25
# Name: 57, dtype: float64, 0    0.25
# Name: 60, dtype: float64, 0    0.0
# Name: 63, dtype: float64, 0    0.166667
# Name: 66, dtype: float64, 0   -0.086957
# Name: 69, dtype: float64, 0    0.0
# Name: 72, dtype: float64, 0    0.5
# ...

# %%
output = pd.DataFrame(alist)

# %%
output.to_csv('Corea.csv', encoding='utf-8', index=False, header=False)

# %%
CoreaVector = pd.read_csv('/Users/halukamaier-borst/Documents/CardiffUniversity/Master Thesis/masterthesis_code/CleanDatasets/ItaloVectorsRatio.csv')
output=output.reset_index()
print(output.head(10))
# Out:
#    index         0
# 0      0  0.133333
# 1      3  0.000000
# 2      6 -0.307692
# 3      9  0.142857
# 4     12  0.000000
# 5     15  0.666667
# 6     18  0.666667
# 7     21  0.000000
# 8     24  1.000000
# 9     27  0.000000

# %%
output=output.ix[:,1]
print(output.head())
# Out:
# 0    0.133333
# 1    0.000000
# 2   -0.307692
# 3    0.142857
# 4    0.000000
# Name: 0, dtype: float64

# %%
CoreaVector.head(10)
# Out:
#    14agree-disagree  DotcountREL  CommacountREL  ExclcountREL  WordcountREL  \
# 0               NaN     0.009091       0.020455      0.000000      0.181818
# 1               1.0     0.024390       0.000000      0.000000      0.195122
# 2               1.0     0.008119       0.021651      0.000000      0.173207
# 3               1.0     0.008547       0.004274      0.000000      0.164530
# 4               1.0     0.036036       0.009009      0.009009      0.189189
# 5               1.0     0.004975       0.004975      0.000000      0.136816
# 6               NaN     0.000000       0.000000      0.098039      0.176471
# 7              -1.0     0.003367       0.016835      0.000000      0.175084
# 8               1.0     0.014286       0.000000      0.000000      0.157143
# 9              -1.0     0.014493       0.000000      0.000000      0.177536
#
#    UppercasecountREL  LowercasecountREL  SpecialcharREL  NumbercountREL  \
# ...

# %%
dataframe=pd.concat([output,CoreaVector], axis=1)
dataframe.head(5)
# Out:
#           0  14agree-disagree  DotcountREL  CommacountREL  ExclcountREL  \
# 0  0.133333               NaN     0.009091       0.020455      0.000000
# 1  0.000000               1.0     0.024390       0.000000      0.000000
# 2 -0.307692               1.0     0.008119       0.021651      0.000000
# 3  0.142857               1.0     0.008547       0.004274      0.000000
# 4  0.000000               1.0     0.036036       0.009009      0.009009
#
#    WordcountREL  UppercasecountREL  LowercasecountREL  SpecialcharREL  \
# 0      0.181818           0.000000           0.959091        0.040909
# 1      0.195122           0.000000           0.951220        0.024390
# 2      0.173207           0.013532           0.920162        0.047361
# 3      0.164530           0.047009           0.908120        0.032051
# 4      0.189189           0.000000           0.927928        0.072072
#
#    NumbercountREL  CharcountREL  UniquewordsREL  ApicescountREL  \
# ...

# %%
dataframe=dataframe.rename(index=str, columns={"0":"Lex","14agree-disagree": "AgreeDisagree"})
dataframe.to_csv("test.csv")

# %%
dataframe = pd.read_csv('/Users/halukamaier-borst/Documents/CardiffUniversity/Master Thesis/masterthesis_code/LexVecMerge.csv')
dataframe.head()
Lexlist=[]
for index,row in dataframe.iterrows():
    if(row["Lex"])<0:
        changeLex=-1
        Lexlist.append(changeLex)
    if(row["Lex"])>0:
        changeLex=1
        Lexlist.append(changeLex)
    else:
        changeLex=0
        Lexlist.append(changeLex)

# %%
LexBinary=pd.DataFrame()
LexBinary["LexBinary"]=Lexlist

# %%
newdataframe=pd.concat([dataframe,LexBinary],axis=1)
newdataframe=newdataframe.dropna()
newdataframe.to_csv("newdataframe3.csv",index=False)
