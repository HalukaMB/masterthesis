# %%
import numpy as np
import pandas as pd
import glob
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import pickle
y_test=[]
pred_test=[]
def kfold(clr,X,y,folds=10):
    from sklearn.cross_validation import StratifiedKFold
    from sklearn import metrics
    mae_sum=0
    acc_sum=0
    kf = StratifiedKFold(y, folds)
    a=0
    for train_index, test_index in kf:
        a+=1
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        clr.fit(X_train, y_train)
        pred_test = clr.predict(X_test)
        
        print (metrics.mean_absolute_error(y_test,pred_test))
        print (metrics.accuracy_score(y_test,pred_test))
        print (confusion_matrix(y_test, clr.predict(X_test)))
        mae_sum+=metrics.mean_absolute_error(y_test,pred_test)
        acc_sum+=metrics.accuracy_score(y_test,pred_test)
    print ('MAE: ',  mae_sum/folds)
    print ('ACC: ',  acc_sum/folds)



#read the dataset
filepath=glob.glob('samplecountsREL/'+'*.csv')
print(filepath)
X = pd.read_csv(filepath[0],
                  engine='python')

X.head()
y=X['botornot']

#changes N, and Y to 0, and 1 respectively

del X['botornot']
del X['user_id']
print(X.head())

#initialize random forests (by defualt it is set to 10 trees)
rf=RandomForestClassifier()

#run algorithm
kfold(rf,np.array(X),y)

#You will get an average AUC around 0.62 as opposed to 0.79 in WEKA
# Out:
# ['samplecountsREL/todayREL.csv']
#              tweet_id  DotcountREL  CommacountREL  ExclcountREL  WordcountREL  \
# 0  891981986260299776     1.971470        0.00000      0.000000      1.158540
# 1  892020237100617728     0.741482        1.84478      2.182216      0.871468
# 2  892054527737769984     0.692459        0.00000      0.000000      0.930115
# 3  891966739092844544     1.971470        0.00000      0.000000      1.158540
# 4  891710333919932416     0.846338        0.00000      0.000000      1.136807
#
#    UppercasecountREL  LowercasecountREL  SpecialcharREL  NumbercountREL  \
# 0           0.433356           1.092399        0.622234        0.000000
# 1           1.195244           0.952714        1.069833        1.688443
# 2           1.420643           0.889725        1.061544        3.153621
# 3           0.433356           1.092399        0.622234        0.000000
# 4           1.116219           0.992290        0.839522        1.445410
#
# ...

# %%
import numpy as np
import pandas as pd
import glob
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix

y_test=[]
pred_test=[]
def kfold(clr,X,y,folds=10):
    from sklearn.cross_validation import StratifiedKFold
    from sklearn import metrics
    mae_sum=0
    acc_sum=0
    kf = StratifiedKFold(y, folds)
    for train_index, test_index in kf:
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        clr = pickle.loads(s)
        pred_test = clr.predict(X_test)
        print (metrics.mean_absolute_error(y_test,pred_test))
        print (metrics.accuracy_score(y_test,pred_test))
        print (confusion_matrix(y_test, clr.predict(X_test)))
        mae_sum+=metrics.mean_absolute_error(y_test,pred_test)
        acc_sum+=metrics.accuracy_score(y_test,pred_test)
    print ('MAE: ',  mae_sum/folds)
    print ('ACC: ',  acc_sum/folds)



#read the dataset
filepath=glob.glob('samplecountsREL/'+'*.csv')
print(filepath)
X = pd.read_csv(filepath[0],
                  engine='python')

X.head()
y=X['botornot']

#changes N, and Y to 0, and 1 respectively

del X['botornot']
del X['user_id']
print(X.head())

#initialize random forests (by defualt it is set to 10 trees)
rf=RandomForestClassifier()

#run algorithm
kfold(rf,np.array(X),y)

#You will get an average AUC around 0.62 as opposed to 0.79 in WEKA
# Out:
# ['samplecountsREL/todayREL.csv']
#              tweet_id  DotcountREL  CommacountREL  ExclcountREL  WordcountREL  \
# 0  891981986260299776     1.971470        0.00000      0.000000      1.158540
# 1  892020237100617728     0.741482        1.84478      2.182216      0.871468
# 2  892054527737769984     0.692459        0.00000      0.000000      0.930115
# 3  891966739092844544     1.971470        0.00000      0.000000      1.158540
# 4  891710333919932416     0.846338        0.00000      0.000000      1.136807
#
#    UppercasecountREL  LowercasecountREL  SpecialcharREL  NumbercountREL  \
# 0           0.433356           1.092399        0.622234        0.000000
# 1           1.195244           0.952714        1.069833        1.688443
# 2           1.420643           0.889725        1.061544        3.153621
# 3           0.433356           1.092399        0.622234        0.000000
# 4           1.116219           0.992290        0.839522        1.445410
#
# ...

# %%
y=X['botornot']

#changes N, and Y to 0, and 1 respectively

del X['botornot']
del X['id']
print(X.head())

#initialize random forests (by defualt it is set to 10 trees)
rf=RandomForestClassifier()

#run algorithm
kfold(rf,np.array(X),y)

#You will get an average AUC around 0.62 as opposed to 0.79 in WEKA
# Out:
# ['samplecountsREL/todayREL.csv']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'botornot'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
testdata = pd.read_csv('/Users/halukamaier-borst/Documents/CardiffUniversity/Master Thesis/botornotREL/botornotwednesdayREL.csv', sep=',',quotechar="'", 
                  engine='python')
testdata=testdata.drop("id",axis=1)
Y_test=testdata["botornot"]
del testdata['botornot']
X_test=testdata
X_test.describe()
# Out:
#         DotcountREL  CommacountREL  ExclcountREL  WordcountREL  \
# count  10000.000000   10000.000000  10000.000000  10000.000000
# mean       1.059157       0.976803      1.083939      0.994020
# std        1.185246       1.830724      4.971496      0.186112
# min        0.000000       0.000000      0.000000      0.157563
# 25%        0.000000       0.000000      0.000000      0.876204
# 50%        0.840453       0.000000      0.000000      1.004203
# 75%        1.583664       2.291105      0.000000      1.125078
# max       16.424862      37.153052    136.607264      1.755702
#
#        UppercasecountREL  LowercasecountREL  SpecialcharREL  NumbercountREL  \
# count       10000.000000       10000.000000    10000.000000    10000.000000
# mean            1.028722           0.993696        1.030095        1.041776
# std             0.788780           0.109874        0.411631        1.390315
# min             0.000000           0.000000        0.192634        0.000000
# ...

# %%
pred_test=rf.predict(X_test)
print (metrics.mean_absolute_error(Y_test,pred_test))
print (metrics.accuracy_score(Y_test,pred_test))
# Out:
# 0.4398
# 0.5602
