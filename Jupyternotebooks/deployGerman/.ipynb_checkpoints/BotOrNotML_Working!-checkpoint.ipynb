# %%
import numpy as np
import pandas as pd
import glob
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import pickle
y_test=[]
pred_test=[]
def kfold(clr,X,y,folds=10):
    from sklearn.cross_validation import StratifiedKFold
    from sklearn import metrics
    mae_sum=0
    acc_sum=0
    kf = StratifiedKFold(y, folds)
    a=0
    for train_index, test_index in kf:
        a+=1
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        clr.fit(X_train, y_train)
        pred_test = clr.predict(X_test)
        if a>9:
            filename = 'trained_model.sav'
            pickle.dump(clr, open(filename, 'wb'))
        print (metrics.mean_absolute_error(y_test,pred_test))
        print (metrics.accuracy_score(y_test,pred_test))
        print (confusion_matrix(y_test, clr.predict(X_test)))
        mae_sum+=metrics.mean_absolute_error(y_test,pred_test)
        acc_sum+=metrics.accuracy_score(y_test,pred_test)
    print ('MAE: ',  mae_sum/folds)
    print ('ACC: ',  acc_sum/folds)



#read the dataset
filepath=glob.glob('samplecountsREL/'+'*.csv')
print(filepath)
X = pd.read_csv(filepath[0],
                  engine='python')

X.head()
y=X['botornot']

#changes N, and Y to 0, and 1 respectively

del X['botornot']
del X['user_id']
print(X.head())

#initialize random forests (by defualt it is set to 10 trees)
rf=RandomForestClassifier()

#run algorithm
kfold(rf,np.array(X),y)

#You will get an average AUC around 0.62 as opposed to 0.79 in WEKA
# Out:
# ['samplecountsREL/todayREL.csv']
#              tweet_id  DotcountREL  CommacountREL  ExclcountREL  WordcountREL  \
# 0  891981986260299776     1.971470        0.00000      0.000000      1.158540
# 1  892020237100617728     0.741482        1.84478      2.182216      0.871468
# 2  892054527737769984     0.692459        0.00000      0.000000      0.930115
# 3  891966739092844544     1.971470        0.00000      0.000000      1.158540
# 4  891710333919932416     0.846338        0.00000      0.000000      1.136807
#
#    UppercasecountREL  LowercasecountREL  SpecialcharREL  NumbercountREL  \
# 0           0.433356           1.092399        0.622234        0.000000
# 1           1.195244           0.952714        1.069833        1.688443
# 2           1.420643           0.889725        1.061544        3.153621
# 3           0.433356           1.092399        0.622234        0.000000
# 4           1.116219           0.992290        0.839522        1.445410
#
#    CharcountREL  UniquewordsREL  QuotescountREL  OpenparREL  CloseparREL  \
# 0           1.0        1.158540        1.324335         0.0          0.0
# 1           1.0        0.871468        0.996181         0.0          0.0
# 2           1.0        0.930115        0.930318         0.0          0.0
# 3           1.0        1.158540        1.324335         0.0          0.0
# 4           1.0        1.136807        1.137056         0.0          0.0
#
#    OperatorcountREL  HashtagcountREL  DottycountREL  LinkcountREL
# 0          0.000000         0.556327            0.0      0.000000
# 1          1.541281         1.255427            0.0      1.994357
# 2          1.919171         0.781616            0.0      1.862499
# 3          0.000000         0.556327            0.0      0.000000
# 4          2.345654         0.477654            0.0      2.276387
# 0.025
# 0.975
# [[97  3]
#  [ 2 98]]
# 0.08
# 0.92
# [[87 13]
#  [ 3 97]]
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 0.08
# 0.92
# [[90 10]
#  [ 6 94]]
# 0.06
# 0.94
# [[92  8]
#  [ 4 96]]
# 0.065
# 0.935
# [[91  9]
#  [ 4 96]]
# 0.035
# 0.965
# [[94  6]
#  [ 1 99]]
# 0.065
# 0.935
# [[ 87  13]
#  [  0 100]]
# 0.08
# 0.92
# [[93  7]
#  [ 9 91]]
# 0.105
# 0.895
# [[85 15]
#  [ 6 94]]
# 0.02
# 0.98
# [[97  3]
#  [ 1 99]]
# MAE:  0.0615
# ACC:  0.9385

# %%
import numpy as np
import pandas as pd
import glob
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix

y_test=[]
pred_test=[]
def kfold(clr,X,y,folds=10):
    from sklearn.cross_validation import StratifiedKFold
    from sklearn import metrics
    mae_sum=0
    acc_sum=0
    kf = StratifiedKFold(y, folds)
    for train_index, test_index in kf:
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        clr = pickle.load(open("trained_model.sav", 'rb'))
        pred_test = clr.predict(X_test)
        print (metrics.mean_absolute_error(y_test,pred_test))
        print (metrics.accuracy_score(y_test,pred_test))
        print (confusion_matrix(y_test, clr.predict(X_test)))
        mae_sum+=metrics.mean_absolute_error(y_test,pred_test)
        acc_sum+=metrics.accuracy_score(y_test,pred_test)
    print ('MAE: ',  mae_sum/folds)
    print ('ACC: ',  acc_sum/folds)



#read the dataset
filepath=glob.glob('countsREL/'+'*.csv')
print(filepath)
X = pd.read_csv(filepath[0],
                  engine='python')

X.head()
y=X['botornot']

#changes N, and Y to 0, and 1 respectively

del X['botornot']
del X['user_id']
print(X.head())

#initialize random forests (by defualt it is set to 10 trees)
rf=RandomForestClassifier()

#run algorithm
kfold(rf,np.array(X),y)

#You will get an average AUC around 0.62 as opposed to 0.79 in WEKA
# Out:
# ['countsREL/todayREL.csv']
#              tweet_id  DotcountREL  CommacountREL  ExclcountREL  WordcountREL  \
# 0  891765079703769089     2.821233       0.000000           0.0      1.142557
# 1  891922729720524801     0.000000       1.609947           0.0      0.726158
# 2  891967198171983875     1.551678       0.000000           0.0      0.977521
# 3  891775030291554304     0.000000       0.000000           0.0      0.954843
# 4  891950406192050176     1.337654       1.734857           0.0      0.842690
#
#    UppercasecountREL  LowercasecountREL  SpecialcharREL  NumbercountREL  \
# 0           1.978483           0.800372        1.647473        1.761795
# 1           0.307247           1.173880        0.567304        0.000000
# 2           1.536234           0.880410        1.418260        2.906961
# 3           0.656510           1.048921        0.740781        1.656388
# 4           1.765786           0.873970        1.358486        1.670667
#
#    CharcountREL  UniquewordsREL  QuotescountREL  OpenparREL  CloseparREL  \
# 0           1.0        1.142557        1.013796         0.0          0.0
# 1           1.0        0.726158        0.892140         0.0          0.0
# 2           1.0        0.977521        2.230351         0.0          0.0
# 3           1.0        0.954843        0.953141         0.0          0.0
# 4           1.0        0.842690        0.961358         0.0          0.0
#
#    OperatorcountREL  HashtagcountREL  DottycountREL  LinkcountREL
# 0          0.000000         4.446423       12.06789      0.000000
# 1          0.000000         0.434761        0.00000      0.000000
# 2          3.640101         0.000000        0.00000      4.705496
# 3          0.000000         0.928977        0.00000      0.000000
# 4          4.184024         1.873971        0.00000      4.056462
# 0.172413793103
# 0.827586206897
# [[192  37]
#  [  8  24]]
# 0.146153846154
# 0.853846153846
# [[195  33]
#  [  5  27]]
# 0.188461538462
# 0.811538461538
# [[187  41]
#  [  8  24]]
# 0.153846153846
# 0.846153846154
# [[195  33]
#  [  7  25]]
# 0.0965250965251
# 0.903474903475
# [[207  21]
#  [  4  27]]
# 0.146718146718
# 0.853281853282
# [[195  33]
#  [  5  26]]
# 0.146718146718
# 0.853281853282
# [[196  32]
#  [  6  25]]
# 0.181467181467
# 0.818532818533
# [[188  40]
#  [  7  24]]
# 0.177606177606
# 0.822393822394
# [[183  45]
#  [  1  30]]
# 0.166023166023
# 0.833976833977
# [[194  34]
#  [  9  22]]
# MAE:  0.157593324662
# ACC:  0.842406675338

# %%
filepath=glob.glob('countsREL/'+'*.csv')
print(filepath)
testdata = pd.read_csv(filepath[0],
                  engine='python')
botornotcount=testdata['botornot'].tolist()
del testdata['botornot']
del testdata['user_id']
#testdata = pd.read_csv('/Users/halukamaier-borst/Documents/CardiffUniversity/Master Thesis/botornotREL/botornotwednesdayREL.csv', sep=',',quotechar="'", 
                 # engine='python')
#testdata=testdata.drop("id",axis=1)
#Y_test=testdata["botornot"]
#del testdata['botornot']
X_test=testdata
from sklearn.cross_validation import StratifiedKFold
from sklearn import metrics

clr = pickle.load(open("trained_model.sav", 'rb'))

X_test.head()
pred_test = clr.predict(X_test)
print(type(pred_test))
pred_test=pred_test.tolist()
print(type(pred_test))
rownew=pd.DataFrame()
rownew["MLbotornot"]=pred_test
rownew2=pd.DataFrame()
rownew2["Countbotornot"]=botornotcount
output=pd.concat([testdata, rownew, rownew2], axis=1)
# Out:
# ['countsREL/todayREL.csv']
# <class 'numpy.ndarray'>
# <class 'list'>

# %%
output.tail()
# Out:
#                 tweet_id  DotcountREL  CommacountREL  ExclcountREL  \
# 2590  891986389641854976     0.000000            0.0      3.237437
# 2591  892025478500036609     0.610897            0.0      8.947562
# 2592  891965674079350784     1.583345            0.0      0.000000
# 2593  892014227749318656     0.760627            0.0      3.713530
# 2594  892063138744610817     0.000000            0.0      9.090723
#
#       WordcountREL  UppercasecountREL  LowercasecountREL  SpecialcharREL  \
# 2590      1.014521           1.313020           0.889303        1.346875
# 2591      0.879659           1.008027           1.018847        1.054699
# 2592      1.211214           1.698217           0.939213        1.125603
# 2593      0.889900           1.255093           0.967771        1.158709
# 2594      1.061308           1.126571           1.013805        1.071574
#
#       NumbercountREL  CharcountREL  UniquewordsREL  QuotescountREL  \
# 2590        1.656388           1.0        1.014521        0.953141
# 2591        1.144473           1.0        0.879659        0.878091
# 2592        0.000000           1.0        1.211214        1.137934
# 2593        0.949987           1.0        0.889900        1.093309
# 2594        0.000000           1.0        1.061308        0.892140
#
#       OpenparREL  CloseparREL  OperatorcountREL  HashtagcountREL  \
# 2590   26.884801    26.884801          0.000000         1.857954
# 2591    0.000000     0.000000          1.910814         0.855829
# 2592    0.000000     0.000000          0.000000         3.327255
# 2593    0.000000     0.000000          1.784363         1.065591
# 2594   25.164174    25.164174          0.000000         0.000000
#
#       DottycountREL  LinkcountREL  MLbotornot  Countbotornot
# 2590            0.0      0.000000           1              1
# 2591            0.0      1.852557           1              1
# 2592            0.0      0.000000           0              1
# 2593            0.0      2.306616           1              1
# 2594            0.0      0.000000           0              1

# %%
MLbotcount=0
Regbotcount=0
for index, row in output.iterrows():
    if row["MLbotornot"]==1:
        MLbotcount+=1
    if row["Countbotornot"]==1:
        Regbotcount+=1
        
print("MLbotcount: ",MLbotcount, "Regbotcount: ",Regbotcount)
# Out:
# MLbotcount:  504 Regbotcount:  314
