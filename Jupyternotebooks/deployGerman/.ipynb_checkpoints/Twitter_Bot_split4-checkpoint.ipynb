# %%
# coding: utf-8

# In[17]:
import csv, glob, re, io, json, time

import pandas as pd

day="today"

CDU=["cdu","csu","merkel", "#cdu","#csu","#merkel", "@CDU"]
SPD=["spd","schulz", "#spd","#schulz",'@spdde']


# In[69]:
filepath=glob.glob('JSONtoCSV/'+'*.csv')
print(filepath)
data = pd.read_csv(filepath[0], skipinitialspace = True, quotechar = "'")


# In[70]:

data=data.sort_values(by='user_id')


# In[71]:

IDbot=0
counter=0
botlist=[]
for cell in data["user_id"]:
    if counter>24:
        if IDbot not in botlist:
            botlist.append(IDbot)
        else:
            pass
    if cell != IDbot:
        IDbot=cell
        counter=1
    else:
        counter+=1


IDnor=0
counter=0
normallist=[]
for cell in data["user_id"]:


    if cell!=IDnor:
        if counter==1:
            normallist.append(IDnor)
            counter=0
        else:
            counter=0
    else:
        pass
    counter+=1
    IDnor=cell
if (counter==1):
    normallist.append(IDnor)



# In[73]:



# In[74]:

frames=[data["text"], data["user_id"],data["tweet_id"]]
reduced_data=pd.concat([data["text"], data["user_id"], data["tweet_id"]], axis=1) 



# In[75]:

botsampleid = []
normalsampleid = []
botsampletext=[]
normalsampletext=[]
bottweetid = []
normaltweetid = []  

progcounter=0
for index, row in reduced_data.iterrows():
    progcounter+=1
    if(row['user_id'])in botlist:
        botsampleid.append(row['user_id'])
        botsampletext.append(row['text'])
        bottweetid.append(row['tweet_id'])


    if(row['user_id'])in normallist:
        normalsampleid.append(row['user_id'])
        normalsampletext.append(row['text'])
        normaltweetid.append(row['tweet_id'])



    if (progcounter%1000==0):
        print(progcounter)




# In[77]:

botdf=pd.DataFrame()
botdf["user_id"]=botsampleid
botdf["text"]=botsampletext
botdf["tweet_id"]=  bottweetid
botdf["botornot"]=1
normaldf=pd.DataFrame()
normaldf["user_id"]=normalsampleid
normaldf["text"]=normalsampletext
normaldf["tweet_id"]= normaltweetid
normaldf["botornot"]=0
normaldf.reset_index(drop=True, inplace=True)
botdf.reset_index(drop=True, inplace=True)
normaldf = normaldf[normaldf.text != 'text']
botdf = botdf[botdf.text != 'text']

purenormal=normaldf
purebot=botdf
purenormal.to_csv("pure/normalpure"+day+".csv", quotechar='"')
purebot.to_csv("pure/botpure"+day+".csv", quotechar='"')


puredf=pd.concat([purenormal,purebot], ignore_index=True)

normaldf=(normaldf.sample(1000, replace=True))
botdf=(botdf.sample(1000, replace=True))

# In[78]:

normaldf.to_csv("sample/normaltweets"+day+".csv", quotechar='"')
botdf.to_csv("sample/bottweets"+day+".csv", quotechar='"')
test=pd.concat([normaldf,botdf], ignore_index=True)
test.head(5)


# In[79]:

test.tail(5)



# In[80]:

data = test
dotcountlist=[]
commacountlist=[]
exclamationcountlist=[]
wordcountlist=[]
uppercasecountlist=[]
lowercasecountlist=[]
charcountlist=[]
specialcharlist=[]
numbercountlist=[]
uniquewordlist=[]
qmarkcountlist=[]
apicescountlist=[]
quotescountlist=[]
openparlist=[]
closeparlist=[]
operatorlist=[]
hashtagcountlist=[]
dottycountlist=[]
linkcountlist=[]

CDUlist=[]
SPDlist=[]
FDPlist=[]
Gruenelist=[]
Linkelist=[]
AFDlist=[]

a=0
#for each cell in the text column of data

for cell in (data['text']):

    a+=1
    dotcount=0
    commacount=0
    qmarkcount=0
    exclamationcount=0
    wordcount=0
    uppercasecount=0
    lowercasecount=0
    charcount=0
    lr_classifier=0
    specialchar=0
    numbercount=0
    cellwordlist=[]
    uniqueword=0
    qmarkcount=0
    apicescount=0
    quotescount=0
    openparcount=0
    closeparcount=0
    operatorcount=0
    hashtagcount=0
    dottycount=0
    linkcount=0
    
    
    dotcount=cell.count(".")
    commacount=cell.count(",")
    exclamationcount=cell.count("!")
    qmarkcount=cell.count("?")
    apicescount=cell.count("'")
    quotescount=cell.count('"')
    openparcount=cell.count('(')
    closeparcount=cell.count(')')
    hashtagcount=cell.count('#')


    if a>10000:
        break
    else:

        #for reach word in cell
        for word in (cell.split()):
       
            
            
            
            
            if word in cellwordlist:
                continue
            else:
                cellwordlist.append(word)
                uniqueword+=1
            if re.search('\.\.\.',word):
                dottycount+=1
            if re.search('http',word):
                linkcount+=1


            wordcount+=1
            uppercaseword=word[1:]
            for c in uppercaseword:
                if c.istitle():
                    uppercasecount+=1
                    #print(word)

            for char in word:
                charcount+=1
                if re.match("[^a-zA-Z0-9]", char):
                    specialchar+=1
                if re.match("[0-9]", char):
                    numbercount+=1
                if char.islower():
                    lowercasecount+=1
                if re.match("[\+\/\-\*\%\=<>&]", char):
                    operatorcount+=1

        #print(cell)
        #print("Dotcount: " + str((dotcount)))
        #print("Commacount: "+ str(commacount))
        #print("Exclamationcount: "+ str(exclamationcount))
        #print("Wordcount: "+ str(wordcount))
        #print("Uppercasecount "+ str(uppercasecount))
        #print("Charcount "+ str(charcount))
        dotcountlist.append(dotcount)
        commacountlist.append(commacount)
        exclamationcountlist.append(exclamationcount)
        wordcountlist.append(wordcount)
        uppercasecountlist.append(uppercasecount)
        lowercasecountlist.append(lowercasecount)
        charcountlist.append(charcount)
        specialcharlist.append(specialchar)
        numbercountlist.append(numbercount)
        uniquewordlist.append(uniqueword)
        qmarkcountlist.append(qmarkcount)
        apicescountlist.append(apicescount)
        quotescountlist.append(quotescount)
        openparlist.append(openparcount)
        closeparlist.append(closeparcount)
        operatorlist.append(operatorcount)
        hashtagcountlist.append(hashtagcount)
        dottycountlist.append(dottycount)
        linkcountlist.append(linkcount)
        
       
    
        
        

row1=pd.DataFrame()
row1["Dotcount"]=dotcountlist
row2=pd.DataFrame()
row2["Commacount"]=commacountlist
row3=pd.DataFrame()
row3["Exclcount"]=exclamationcountlist
row4=pd.DataFrame()
row4["Wordcount"]=wordcountlist
row5=pd.DataFrame()
row5["Uppercasecount"]=uppercasecountlist
row6=pd.DataFrame()
row6["Lowercasecount"]=lowercasecountlist
row7=pd.DataFrame()
row7["Specialchar"]=specialcharlist
row8=pd.DataFrame()
row8["Numbercount"]=numbercountlist
row9=pd.DataFrame()
row9["Charcount"]=charcountlist
row10=pd.DataFrame()
row10["Uniquewords"]=uniquewordlist
row11=pd.DataFrame()
row11["Qmarkcount"]=qmarkcountlist
row11=pd.DataFrame()
row11["Apicescount"]=apicescountlist
row12=pd.DataFrame()
row12["Quotescount"]=quotescountlist
row13=pd.DataFrame()
row13["Openpar"]=openparlist
row14=pd.DataFrame()
row14["Closepar"]=closeparlist
row15=pd.DataFrame()
row15["Operatorcount"]=operatorlist
row16=pd.DataFrame()
row16["Hashtagcount"]=hashtagcountlist
row17=pd.DataFrame()
row17["Dottycount"]=dottycountlist
row18=pd.DataFrame()
row18["Linkcount"]=linkcountlist

output=pd.concat([data, row1, row2, row3, row4, row5, row6, row7, row8, row9, row10, row11, row12, row13, row14, row15, row16, row17, row18],axis=1)
output.to_csv("samplecounts/"+day+"counts.csv", index=False)


# In[83]:
new_datareduced=output.ix[:,[0,2,3]]
datareduced=output.ix[:,3:]
print(datareduced.head(10))
datareduced.describe()
c=0
limit=0
for column in datareduced:
    limit+=1
print(limit)
a=-1
for column in datareduced:
    lista=[]
    a+=1
    columnmean=((datareduced.ix[:, a]).mean())/datareduced['Charcount'].mean()
    print(column,":" ,columnmean)
    b=-1
    for index, row in (datareduced).iterrows():
        b+=1
        columnval=(datareduced.ix[b, a])
        columnratio=columnval/datareduced.ix[b,'Charcount']
        columnREL=(columnratio/columnmean)
        lista.append(columnREL)
    c+=1
    print(c)
    if c>limit:
        print("Limit!")
        break
    else:
        column = pd.DataFrame({(column+"REL") : lista})
        #print(column)
        new_datareduced=pd.concat([new_datareduced, column], axis=1)
        #print(datareduced)
print("STOP!")


# In[84]:

new_datareduced=new_datareduced.drop("ApicescountREL", axis=1)
new_datareduced=new_datareduced.drop("botornotREL", axis=1)
new_datareduced.to_csv('samplecountsREL/'+day+'REL.csv', encoding='utf-8', index=False)

# In[ ]:
# Out:
# ['JSONtoCSV/2017-08-02 18:25:00.csv', 'JSONtoCSV/2017-08-02 18:25:22.csv', 'JSONtoCSV/2017-08-02 18:25:51.csv', 'JSONtoCSV/2017-Aug-01.csv', 'JSONtoCSV/2017-Aug-02--17-54-45.csv', 'JSONtoCSV/2017-Aug-02--17-54-58.csv', 'JSONtoCSV/2017-Aug-02--17-55-17.csv', 'JSONtoCSV/2017-Aug-02--17-58-41.csv', 'JSONtoCSV/2017-Aug-02--17-59-52.csv', 'JSONtoCSV/2017-Aug-02--18-00-25.csv', 'JSONtoCSV/2017-Aug-02.csv']
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
#    botornot  Dotcount  Commacount  Exclcount  Wordcount  Uppercasecount  \
# 0         0         1           0          1         13               7
# 1         0         4           0          0         18              17
# 2         0         1           0          0         16               5
# 3         0         2           2          0         12              17
# 4         0         2           1          0         18               3
# 5         0         1           0          0         14               6
# 6         0         0           0          4          6               0
# 7         0         2           0          1         11              14
# 8         0         1           1          1         18               5
# 9         0         2           0          0         14               3
#
#    Lowercasecount  Specialchar  Numbercount  Charcount  Uniquewords  \
# 0              95           13            3        121           13
# 1              66           23            4        110           18
# 2              96           11            0        115           16
# 3              68           18           10        113           12
# 4              82            9            0        100           18
# 5              75            7            1         89           14
# 6              51           13            0         64            6
# 7              66           14            1         96           11
# 8              73           21            0        105           18
# 9              69            7            0         85           14
#
#    Apicescount  Quotescount  Openpar  Closepar  Operatorcount  Hashtagcount  \
# 0            0            2        0         0              4             2
# 1            0            2        0         0              0             9
# 2            0            2        0         0              1             0
# 3            0            2        0         0              3             2
# 4            0            2        0         0              0             1
# 5            0            2        0         0              3             0
# 6            0            2        0         0              0             0
# 7            0            2        0         0              3             1
# 8            0            2        0         0              0             0
# 9            0            2        0         0              0             1
#
#    Dottycount  Linkcount
# 0           0          0
# 1           1          0
# 2           0          0
# 3           0          1
# 4           0          0
# 5           0          1
# 6           0          0
# 7           0          1
# 8           0          0
# 9           0          0
# 19
# botornot : 0.00439989792237
# 1
# Dotcount : 0.012412112039
# 2
# Commacount : 0.00449229577874
# 3
# Exclcount : 0.00391150925299
# 4
# Wordcount : 0.141012328514
# 5
# Uppercasecount : 0.0811737167698
# 6
# Lowercasecount : 0.745391106926
# 7
# Specialchar : 0.131222555637
# 8
# Numbercount : 0.0203187286055
# 9
# Charcount : 1.0
# 10
# Uniquewords : 0.141012328514
# 11
# Apicescount : 0.0
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:355: RuntimeWarning: invalid value encountered in double_scalars
# 12
# Quotescount : 0.0175995916895
# 13
# Openpar : 0.000439989792237
# 14
# Closepar : 0.000431189996392
# 15
# Operatorcount : 0.0165876151673
# 16
# Hashtagcount : 0.0209347143146
# 17
# Dottycount : 0.000611585811209
# 18
# Linkcount : 0.00438229833068
# 19
# STOP!

# %%
print(botlist)
botdf=pd.DataFrame()
botdf["bot_ids"]=botlist
botdf.to_csv("botlist/"+day+"botlist.csv", index=False)
# Out:
# ['1367260729', '2377440392', '2601075054', '277164221', '4228788018', '4802702181', '4830265798', '792963286081888256', 'user_id']

# %%
data = puredf
dotcountlist=[]
commacountlist=[]
exclamationcountlist=[]
wordcountlist=[]
uppercasecountlist=[]
lowercasecountlist=[]
charcountlist=[]
specialcharlist=[]
numbercountlist=[]
uniquewordlist=[]
qmarkcountlist=[]
apicescountlist=[]
quotescountlist=[]
openparlist=[]
closeparlist=[]
operatorlist=[]
hashtagcountlist=[]
dottycountlist=[]
linkcountlist=[]

a=0
#for each cell in the text column of data

for cell in (data['text']):

    a+=1
    dotcount=0
    commacount=0
    qmarkcount=0
    exclamationcount=0
    wordcount=0
    uppercasecount=0
    lowercasecount=0
    charcount=0
    lr_classifier=0
    specialchar=0
    numbercount=0
    cellwordlist=[]
    uniqueword=0
    qmarkcount=0
    apicescount=0
    quotescount=0
    openparcount=0
    closeparcount=0
    operatorcount=0
    hashtagcount=0
    dottycount=0
    linkcount=0
    
    CDUcount=0
    SPDcount=0
    FDPcount=0
    Gruenecount=0
    Linkecount=0
    AFDcount=0



    dotcount=cell.count(".")
    commacount=cell.count(",")
    exclamationcount=cell.count("!")
    qmarkcount=cell.count("?")
    apicescount=cell.count("'")
    quotescount=cell.count('"')
    openparcount=cell.count('(')
    closeparcount=cell.count(')')
    hashtagcount=cell.count('#')


    if a>10000:
        break
    else:

        #for reach word in cell
        for word in (cell.split()):
            word=str(word)
            
            if re.search('cdu',word):
                linkcount+=1

            if word.lower() in CDU:
                CDUcount+=1
            if word.lower() in SPD:
                SPDcount+=1
            
           
            
            if word in cellwordlist:
                continue
            else:
                cellwordlist.append(word)
                uniqueword+=1
            if re.search('\.\.\.',word):
                dottycount+=1
            if re.search('http',word):
                linkcount+=1


            wordcount+=1
            uppercaseword=word[1:]
            for c in uppercaseword:
                if c.istitle():
                    uppercasecount+=1
                    #print(word)

            for char in word:
                charcount+=1
                if re.match("[^a-zA-Z0-9]", char):
                    specialchar+=1
                if re.match("[0-9]", char):
                    numbercount+=1
                if char.islower():
                    lowercasecount+=1
                if re.match("[\+\/\-\*\%\=<>&]", char):
                    operatorcount+=1

        #print(cell)
        #print("Dotcount: " + str((dotcount)))
        #print("Commacount: "+ str(commacount))
        #print("Exclamationcount: "+ str(exclamationcount))
        #print("Wordcount: "+ str(wordcount))
        #print("Uppercasecount "+ str(uppercasecount))
        #print("Charcount "+ str(charcount))
        dotcountlist.append(dotcount)
        commacountlist.append(commacount)
        exclamationcountlist.append(exclamationcount)
        wordcountlist.append(wordcount)
        uppercasecountlist.append(uppercasecount)
        lowercasecountlist.append(lowercasecount)
        charcountlist.append(charcount)
        specialcharlist.append(specialchar)
        numbercountlist.append(numbercount)
        uniquewordlist.append(uniqueword)
        qmarkcountlist.append(qmarkcount)
        apicescountlist.append(apicescount)
        quotescountlist.append(quotescount)
        openparlist.append(openparcount)
        closeparlist.append(closeparcount)
        operatorlist.append(operatorcount)
        hashtagcountlist.append(hashtagcount)
        dottycountlist.append(dottycount)
        linkcountlist.append(linkcount)
        
        CDUlist.append(CDUcount)
        SPDlist.append(SPDcount)
        
    

row1=pd.DataFrame()
row1["Dotcount"]=dotcountlist
row2=pd.DataFrame()
row2["Commacount"]=commacountlist
row3=pd.DataFrame()
row3["Exclcount"]=exclamationcountlist
row4=pd.DataFrame()
row4["Wordcount"]=wordcountlist
row5=pd.DataFrame()
row5["Uppercasecount"]=uppercasecountlist
row6=pd.DataFrame()
row6["Lowercasecount"]=lowercasecountlist
row7=pd.DataFrame()
row7["Specialchar"]=specialcharlist
row8=pd.DataFrame()
row8["Numbercount"]=numbercountlist
row9=pd.DataFrame()
row9["Charcount"]=charcountlist
row10=pd.DataFrame()
row10["Uniquewords"]=uniquewordlist
row11=pd.DataFrame()
row11["Qmarkcount"]=qmarkcountlist
row11=pd.DataFrame()
row11["Apicescount"]=apicescountlist
row12=pd.DataFrame()
row12["Quotescount"]=quotescountlist
row13=pd.DataFrame()
row13["Openpar"]=openparlist
row14=pd.DataFrame()
row14["Closepar"]=closeparlist
row15=pd.DataFrame()
row15["Operatorcount"]=operatorlist
row16=pd.DataFrame()
row16["Hashtagcount"]=hashtagcountlist
row17=pd.DataFrame()
row17["Dottycount"]=dottycountlist
row18=pd.DataFrame()
row18["Linkcount"]=linkcountlist

output=pd.concat([data, row1, row2, row3, row4, row5, row6, row7, row8, row9, row10, row11, row12, row13, row14, row15, row16, row17, row18],axis=1)
output.to_csv("counts/"+day+"counts.csv", index=False)


# In[83]:
new_datareduced=output.ix[:,[0,2,3]]
datareduced=output.ix[:,3:]
print(datareduced.head(10))
datareduced.describe()
c=0
limit=0
for column in datareduced:
    limit+=1
print(limit)
a=-1
for column in datareduced:
    lista=[]
    a+=1
    columnmean=((datareduced.ix[:, a]).mean())/datareduced['Charcount'].mean()
    print(column,":" ,columnmean)
    b=-1
    for index, row in (datareduced).iterrows():
        b+=1
        columnval=(datareduced.ix[b, a])
        columnratio=columnval/datareduced.ix[b,'Charcount']
        columnREL=(columnratio/columnmean)
        lista.append(columnREL)
    c+=1
    print(c)
    if c>limit:
        print("Limit!")
        break
    else:
        column = pd.DataFrame({(column+"REL") : lista})
        #print(column)
        new_datareduced=pd.concat([new_datareduced, column], axis=1)
        #print(datareduced)
print("STOP!")


# In[84]:

new_datareduced=new_datareduced.drop("ApicescountREL", axis=1)
new_datareduced=new_datareduced.drop("botornotREL", axis=1)
new_datareduced.to_csv('countsREL/'+day+'REL.csv', encoding='utf-8', index=False)

# In[ ]:
# Out:
#    botornot  Dotcount  Commacount  Exclcount  Wordcount  Uppercasecount  \
# 0         0         4           0          0         18              17
# 1         0         0           1          0         13               3
# 2         0         1           0          0          7               6
# 3         0         1           0          0         17               9
# 4         0         0           0          0         16               6
# 5         0         2           1          0         14              16
# 6         0         2           0          0         14               3
# 7         0         1           0          1         13               4
# 8         0         0           3          0         18              19
# 9         0         0           1          0         19              13
#
#    Lowercasecount  Specialchar  Numbercount  Charcount  Uniquewords  \
# 0              66           23            4        110           18
# 1             110            9            0        125           13
# 2              33            9            3         50            7
# 3              94           13            0        119           17
# 4              92           11            4        117           16
# 5              76           20            4        116           14
# 6              69            7            0         85           14
# 7              57           13            2         77           13
# 8              88           18            2        128           18
# 9              97           18            2        129           19
#
#    Apicescount  Quotescount  Openpar  Closepar  Operatorcount  Hashtagcount  \
# 0            0            2        0         0              0             9
# 1            0            2        0         0              0             1
# 2            0            2        0         0              3             0
# 3            0            2        0         0              0             5
# 4            0            2        0         0              0             2
# 5            0            2        0         0              8             4
# 6            0            2        0         0              0             1
# 7            0            2        0         0              3             0
# 8            0            2        0         0              1             2
# 9            0            2        0         0              1             4
#
#    Dottycount  Linkcount
# 0           1          0
# 1           0          0
# 2           0          1
# 3           0          0
# 4           0          0
# 5           0          2
# 6           0          0
# 7           0          1
# 8           0          0
# 9           0          0
# 19
# botornot : 0.000961880767862
# 1
# Dotcount : 0.0127714489142
# 2
# Commacount : 0.00501821069639
# 3
# Exclcount : 0.00250568228496
# 4
# Wordcount : 0.143409234055
# 5
# Uppercasecount : 0.0786243393488
# 6
# Lowercasecount : 0.749907577293
# 7
# Specialchar : 0.126037188159
# 8
# Numbercount : 0.0205965714599
# 9
# Charcount : 1.0
# 10
# Uniquewords : 0.143409234055
# 11
# Apicescount : 0.0
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:214: RuntimeWarning: invalid value encountered in double_scalars
# 12
# Quotescount : 0.0179300052031
# 13
# Openpar : 0.000297806501082
# 14
# Closepar : 0.000294383437851
# 15
# Operatorcount : 0.0163964728756
# 16
# Hashtagcount : 0.0177314675357
# 17
# Dottycount : 0.000684612646165
# 18
# Linkcount : 0.00446709751623
# 19
# STOP!

# %%
new_datareduced.head()
# Out:
#       user_id            tweet_id  botornot  DotcountREL  CommacountREL  \
# 0  1002119688  891765079703769089         0     2.847260       0.000000
# 1  1003379274  891922729720524801         0     0.000000       1.594194
# 2   100816694  891967198171983875         0     1.565993       0.000000
# 3   101046548  891778206960951296         0     0.657980       0.000000
# 4  1015372614  891775030291554304         0     0.000000       0.000000
#
#    ExclcountREL  WordcountREL  UppercasecountREL  LowercasecountREL  \
# 0           0.0      1.141045           1.965618           0.800099
# 1           0.0      0.725197           0.305249           1.173478
# 2           0.0      0.976227           1.526245           0.880108
# 3           0.0      0.996150           0.961919           1.053351
# 4           0.0      0.953580           0.652241           1.048562
#
#    SpecialcharREL  NumbercountREL  CharcountREL  UniquewordsREL  \
# 0        1.658962        1.765519           1.0        1.141045
# 1        0.571260        0.000000           1.0        0.725197
# 2        1.428150        2.913106           1.0        0.976227
# 3        0.866758        0.000000           1.0        0.996150
# 4        0.745947        1.659890           1.0        0.953580
#
#    QuotescountREL  OpenparREL  CloseparREL  OperatorcountREL  HashtagcountREL  \
# 0        1.014044         0.0          0.0          0.000000         4.614293
# 1        0.892359         0.0          0.0          0.000000         0.451175
# 2        2.230897         0.0          0.0          3.659324         0.000000
# 3        0.937352         0.0          0.0          0.000000         2.369618
# 4        0.953375         0.0          0.0          0.000000         0.964050
#
#    DottycountREL  LinkcountREL
# 0      13.278909       0.00000
# 1       0.000000       0.00000
# 2       0.000000       4.47718
# 3       0.000000       0.00000
# 4       0.000000       0.00000

# %%
rown1=pd.DataFrame()
rown1["CDU"]=CDUlist
rown2=pd.DataFrame()
rown2["SPD"]=SPDlist
rown3=pd.DataFrame()
rown3["FDP"]=FDPlist
rown4=pd.DataFrame()
rown4["Gruene"]=Gruenelist
rown5=pd.DataFrame()
rown5["Linke"]=Linkelist
rown6=pd.DataFrame()
rown6["AFD"]=AFDlist

new=pd.concat([rown1, rown2], axis=1)
print(len(new_datareduced))
print(len(new))
# Out:
# 2619
# 2619

# %%
test=pd.concat([new_datareduced, new], axis=1)
test.head()
# Out:
#       user_id            tweet_id  botornot  DotcountREL  CommacountREL  \
# 0  1002119688  891765079703769089         0     2.847260       0.000000
# 1  1003379274  891922729720524801         0     0.000000       1.594194
# 2   100816694  891967198171983875         0     1.565993       0.000000
# 3   101046548  891778206960951296         0     0.657980       0.000000
# 4  1015372614  891775030291554304         0     0.000000       0.000000
#
#    ExclcountREL  WordcountREL  UppercasecountREL  LowercasecountREL  \
# 0           0.0      1.141045           1.965618           0.800099
# 1           0.0      0.725197           0.305249           1.173478
# 2           0.0      0.976227           1.526245           0.880108
# 3           0.0      0.996150           0.961919           1.053351
# 4           0.0      0.953580           0.652241           1.048562
#
#    SpecialcharREL ...   UniquewordsREL  QuotescountREL  OpenparREL  \
# 0        1.658962 ...         1.141045        1.014044         0.0
# 1        0.571260 ...         0.725197        0.892359         0.0
# 2        1.428150 ...         0.976227        2.230897         0.0
# 3        0.866758 ...         0.996150        0.937352         0.0
# 4        0.745947 ...         0.953580        0.953375         0.0
#
#    CloseparREL  OperatorcountREL  HashtagcountREL  DottycountREL  \
# 0          0.0          0.000000         4.614293      13.278909
# 1          0.0          0.000000         0.451175       0.000000
# 2          0.0          3.659324         0.000000       0.000000
# 3          0.0          0.000000         2.369618       0.000000
# 4          0.0          0.000000         0.964050       0.000000
#
#    LinkcountREL  CDU  SPD
# 0       0.00000    2    1
# 1       0.00000    0    0
# 2       4.47718    0    0
# 3       0.00000    1    0
# 4       0.00000    0    0
#
# [5 rows x 22 columns]

# %%
botnumber=0
CDUnumber=0
SPDnumber=0
CDUbotnumber=0
SPDbotnumber=0
for index, row in test.iterrows():
    if row["botornot"]==1:
        botnumber+=1
    if row["CDU"]>0:
        CDUnumber+=1
    if row["SPD"]>0:
        SPDnumber+=1
    if row["CDU"]>0 and row["botornot"]==1:
        CDUbotnumber+=1
    if row["SPD"]>0 and row["botornot"]==1:
        SPDbotnumber+=1
overall=len(test)
normalnumber=overall-botnumber

# %%
print("tweets by bots:", botnumber,"//","tweets in general:", normalnumber)
print("tweets by bots about CDU", CDUbotnumber, "//","tweets about CDU:", CDUnumber)
print("tweets by bots about SPD", SPDbotnumber, "//","tweets about SPD:",  SPDnumber)
# Out:
# tweets by bots: 281 // tweets in general: 2338
# tweets by bots about CDU 92 // tweets about CDU: 680
# tweets by bots about SPD 34 // tweets about SPD: 404

# %%
quota=botnumber/normalnumber
quota
# Out:
# 0.13765892152564665
